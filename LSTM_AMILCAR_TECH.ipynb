# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('data_dim_vente.csv',engine='python')
x=dataset.iloc[:,7].values
y=dataset.iloc[:,5].values
dataset
# Out:
#        ID_VENTE                          ID_ARTICLE ID_CLIENT  \
# 0             1  ML1212            003001         X  SC000019
# 1             2  ML1212            003007         X  SC000019
# 2             3  ML1212            004001         X  SC000019
# 3             4  ML1212            004007         X  SC000019
# 4             5  ML1212            005001         X  SC000019
# 5             6  ML1212            005007         X  SC000019
# 6             7  ML1212            007001         X  SC000019
# 7             8  ML1212            007007         X  SC000019
# 8             9  ML1212            008001         X  SC000019
# 9            10  ML1212            008007         X  SC000019
# 10           11  ML1212            009001         X  SC000019
# 11           12  ML1212            009007         X  SC000019
# 12           14  ML1512            00300D         X  SC000019
# 13           16  ML1512            00400D         X  SC000019
# ...

# %%
df1=dataset.reset_index()['PRIX_VENTE']

# %%
df1
# Out:
# 0         96.88
# 1         96.88
# 2        193.75
# 3        193.75
# 4        290.63
# 5        290.63
# 6        193.75
# 7        193.75
# 8        193.75
# 9        193.75
# 10        96.88
# 11        96.88
# 12        96.88
# 13       193.75
# 14        96.88
# 15       290.63
# 16       193.75
# 17       193.75
# 18        96.88
# 19        58.60
# 20        14.99
# 21        23.44
# 22        46.88
# 23        70.32
# 24        46.88
# 25        23.44
# 26        46.88
# 27        46.88
# 28        23.44
# 29        46.88
#           ...
# 10407    132.00
# 10408    175.00
# 10409    137.50
# 10410    460.00
# 10411    230.00
# 10412    460.00
# 10413    460.00
# 10414     12.00
# 10415      4.00
# 10416      8.00
# 10417      4.00
# 10418     42.00
# 10419     21.00
# 10420     69.00
# 10421     18.00
# 10422     18.00
# 10423     18.00
# 10424     18.00
# 10425     18.00
# 10426     18.00
# 10427     36.00
# 10428     18.00
# 10429     18.00
# 10430     18.00
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
df1
# Out:
# 0         96.88
# 1         96.88
# 2        193.75
# 3        193.75
# 4        290.63
# 5        290.63
# 6        193.75
# 7        193.75
# 8        193.75
# 9        193.75
# 10        96.88
# 11        96.88
# 12        96.88
# 13       193.75
# 14        96.88
# 15       290.63
# 16       193.75
# 17       193.75
# 18        96.88
# 19        58.60
# 20        14.99
# 21        23.44
# 22        46.88
# 23        70.32
# 24        46.88
# 25        23.44
# 26        46.88
# 27        46.88
# 28        23.44
# 29        46.88
#           ...
# 10407    132.00
# 10408    175.00
# 10409    137.50
# 10410    460.00
# 10411    230.00
# 10412    460.00
# 10413    460.00
# 10414     12.00
# 10415      4.00
# 10416      8.00
# 10417      4.00
# 10418     42.00
# 10419     21.00
# 10420     69.00
# 10421     18.00
# 10422     18.00
# 10423     18.00
# 10424     18.00
# 10425     18.00
# 10426     18.00
# 10427     36.00
# 10428     18.00
# 10429     18.00
# 10430     18.00
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
df1
# Out:
# array([[0.0945159 ],
#        [0.0945159 ],
#        [0.0993034 ],
#        ...,
#        [0.0906175 ],
#        [0.09773425],
#        [0.08996513]])

# %%
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (6784, 3653)

# %%
train_data
# Out:
# array([[0.0945159 ],
#        [0.0945159 ],
#        [0.0993034 ],
#        ...,
#        [0.09670282],
#        [0.11065215],
#        [0.09670282]])

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (6683, 100)
# (6683,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (3552, 100)
# (3552,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
## Create the Stacked LSTM model
import tensorflow as tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=10,batch_size=64,verbose=1)
# Out:
# Train on 6683 samples, validate on 3552 samples
# Epoch 1/10
# 6683/6683 [==============================] - 45s 7ms/sample - loss: 0.0018 - val_loss: 0.0015
# Epoch 2/10
# 6683/6683 [==============================] - 26s 4ms/sample - loss: 0.0012 - val_loss: 0.0014
# Epoch 3/10
# 6683/6683 [==============================] - 26s 4ms/sample - loss: 0.0011 - val_loss: 0.0014
# Epoch 4/10
# 6683/6683 [==============================] - 26s 4ms/sample - loss: 0.0011 - val_loss: 0.0013
# Epoch 5/10
# 6683/6683 [==============================] - 26s 4ms/sample - loss: 0.0010 - val_loss: 0.0012
# Epoch 6/10
# 6683/6683 [==============================] - 26s 4ms/sample - loss: 9.4328e-04 - val_loss: 0.0011
# Epoch 7/10
# 6683/6683 [==============================] - 26s 4ms/sample - loss: 9.3559e-04 - val_loss: 0.0011
# Epoch 8/10
# 6683/6683 [==============================] - 26s 4ms/sample - loss: 9.2915e-04 - val_loss: 0.0010
# Epoch 9/10
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 0.030024821515501086

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 0.03141542516506969

# %%
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
#green is test data
# blue is total dataset

# %%
len(test_data),len(train_data)
# Out:
# (3653, 6784)

# %%
x_input=test_data[3553:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
len(temp_input)
# Out:
# 100

# %%
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<360):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# 0 day input [0.09229785 0.09229785 0.09229785 0.09229785 0.09229785 0.09578209
#  0.09069658 0.09069658 0.09069658 0.09069658 0.09214958 0.09505559
#  0.09069658 0.09069658 0.09069658 0.09069658 0.09069658 0.09069658
#  0.09032097 0.08991472 0.10870591 0.09200131 0.09541142 0.09086461
#  0.09200131 0.09101288 0.09101288 0.09486778 0.09101288 0.09229785
#  0.09101288 0.09021224 0.09086461 0.09101288 0.09214958 0.1003289
#  0.1028     0.09811727 0.09711648 0.11808372 0.0962516  0.09837674
#  0.09652342 0.11246198 0.10109494 0.11246198 0.11246198 0.09032097
#  0.0899256  0.09012328 0.0899256  0.09180363 0.09076577 0.09313802
#  0.0906175  0.0906175  0.0906175  0.0906175  0.0906175  0.0906175
#  0.0915071  0.0906175  0.0906175  0.0906175  0.0906175  0.0906175
#  0.0906175  0.0906175  0.09773425 0.08996513 0.09001556 0.08953719
#  0.08878775 0.08798157 0.087194   0.08644725 0.085747   0.085094
#  0.08448687 0.08392316 0.08339955 0.08291239 0.08245786 0.08203228
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,461)

# %%
import matplotlib.pyplot as plt

# %%
len(df1)
# Out:
# 10437

# %%
plt.plot(day_new,scaler.inverse_transform(df1[10337:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %% [markdown]
# # this orange part of graph is the future prediction for 360 days it can also be increased to 2 years(720) days

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[10000:])

# %% [markdown]
# # epoch should be increased from 10 to 100 for better model  i have taken 10 due to my laptop specifications , It was lagging and taking to much time..            at the time of fitting data to the model

# %% [markdown]
# # at the time of taken n_steps they are taken as 100 but can be increased to atleast 1000 for better accuracy.
